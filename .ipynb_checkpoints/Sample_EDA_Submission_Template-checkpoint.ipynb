# %% [markdown]
# <a href="https://colab.research.google.com/github/nischal-bellana/Paisabazaar-Banking-Fraud-Analysis/blob/master/Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - PaisaBazaar Banking Fraud Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### Team Member 1 - Nischal Bellana

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Dataset contains details about the customers' financial data regarding their management of credit card and loans, their corresponding credit scores and other details. Some analysis has been done by me focusing on affects of the other customer details on their credit score. Some Important results are positive correlation between Annual Income and Credit Score, Credit Utilization Ratio has a little positive correlation where as No of loans has very prominent negative correlation with credit score, in all age groups the dominant credit score is 'Standard' and least dominant is 'Good.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/nischal-bellana/Paisabazaar-Banking-Fraud-Analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Business Context**
#
# Paisabazaar is a financial services company that assists customers in finding and applying for various banking and credit products. An integral part of their service is assessing the creditworthiness of individuals, which is crucial for both loan approval and risk management. The credit score of a person is a significant metric used by financial institutions to determine the likelihood that an individual will repay their loans or credit balances. Accurate classification of credit scores can help Paisabazaar enhance their credit assessment processes, reduce the risk of loan defaults, and offer personalized financial advice to their customers.
#
# In this context, analyzing and classifying credit scores based on customer data can improve decision-making processes and contribute to better financial product recommendations. This case study aims to develop a model that predicts the credit score of individuals based on various features, such as income, credit card usage, and payment behavior.
#
# **Dataset Description**
#
# ![paisabazar1_9334977f6b.png](data:image/png;base64,...)
#
# **Main Libraries to be used:**
#
# Pandas: For data manipulation, cleaning, and analysis.
# NumPy: For efficient numerical computations and array handling.
# Matplotlib: For creating basic static visualizations like line and bar charts.
# Seaborn: For advanced statistical visualizations and better aesthetics.
# Plotly: For interactive and dynamic data visualizations.
#
# **Project Architecture:**
#
# ![Paisabazaar_banking_Fraud_Analysis_153874c7e5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The Objective of this project is to learn about how different aspects of customers financial data relate to their credit score.
#
# The Key Enquiries that need to be answered are:
#
#
#
# *   Does a higher annual income correlate with higher credit score?
# *   Does the credit utilization ratio have a greater impact on the credit scores than  the total number of loans taken?
# *   Is having higher number of credit cards associated with a higher credit score assuming the credit utilization ratio is managed well?
# *   Is there a negative correlation between the number of delayed payments and credit score?
# *   What is the distribution of credit scores across different age groups?
# *   Are there noticeable trends or seasonal patterns in credit scores based on month of the year?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data = pd.read_csv("https://raw.githubusercontent.com/nischal-bellana/Paisabazaar-Banking-Fraud-Analysis/refs/heads/master/dataset.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head(5)
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset
data.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_data_count = data.isnull().sum()
null_data_count

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * The dataset consists of records of monthly credit card usage related details and other financial details of customers.
# * The primary key for the data set is the column 'ID'.
# * Each customer is uniquely identifies by their id called 'Customer_ID'.
# * Each customer has 8 records from 1st month to 8th month in the dataset.
# * The key column that is of interest to us the 'Credit_Score' column.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns

# %%
# Dataset Describe
data.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# | Column Name              | Description                                                                 |
# |---------------------------|------------------------------------------------------------------------------|
# | ID                        | Unique ID of the record                                                      |
# | Customer_ID               | Unique ID of the customer                                                    |
# | Month                     | Month of the year                                                           |
# | Name                      | The name of the person                                                      |
# | Age                       | The age of the person                                                       |
# | SSN                       | Social Security Number of the person                                        |
# | Occupation                | The occupation of the person                                                |
# | Annual_Income             | The Annual Income of the person                                             |
# | Monthly_Inhand_Salary     | Monthly in-hand salary of the person                                        |
# | Num_Bank_Accounts         | The number of bank accounts of the person                                   |
# | Num_Credit_Card           | Number of credit cards the person is having                                 |
# | Interest_Rate             | The interest rate on the credit card of the person                          |
# | Num_of_Loan               | The number of loans taken by the person from the bank                       |
# | Type_of_Loan              | The types of loans taken by the person from the bank                        |
# | Delay_from_due_date       | The average number of days delayed by the person from the date of payment   |
# | Num_of_Delayed_Payment    | Number of payments delayed by the person                                    |
# | Changed_Credit_Card       | The percentage change in the credit card limit of the person                |
# | Num_Credit_Inquiries      | The number of credit card inquiries by the person                           |
# | Credit_Mix                | Classification of Credit Mix of the customer                                |
# | Outstanding_Debt          | The outstanding balance of the person                                       |
# | Credit_Utilization_Ratio  | The credit utilization ratio of the credit card of the customer             |
# | Credit_History_Age        | The age of the credit history of the person                                 |
# | Payment_of_Min_Amount     | Yes if the person paid the minimum amount to be paid only, otherwise no     |
# | Total_EMI_per_month       | The total EMI per month of the person                                       |
# | Amount_invested_monthly   | The monthly amount invested by the person                                   |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
data.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# No Data Wrangling required.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# There are no null values and no duplicate rows in the data set.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#Credit Score vs Annual Income
grouped_data = data.groupby('Credit_Score')['Annual_Income'].mean().reindex(['Poor','Standard','Good'])

plt.figure(figsize=(8,6))
sns.barplot(
    x=grouped_data.index,
    y=grouped_data.values,
    hue=grouped_data.index,
    palette='viridis',
    legend=False
)
plt.title('Average Annual Income by Credit Score Category')
plt.xlabel('Credit Score Category')
plt.ylabel('Average Annual Income')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Credit_Score is categorical while Annual_Income is numerical. So Bar plot of average annual income across different categories in Credit_Score can show us the trend of annual income vs credit score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the plot we can see that as we go from poor to good the average annual income is increasing. Therefore our assumption regarding positive correlation b/w Annual_Income and Credit_Score is correct.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight observed is helpful in creating positive impact. It allows us to have a positive weightage on a parameter ie annual income in estimating the credit score.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Credit score vs Credit Utilization Ratio and Number of Loans

grouped_data = data.groupby('Credit_Score')[['Credit_Utilization_Ratio', 'Num_of_Loan']].mean().reindex(['Poor', 'Standard', 'Good'])

# Normalize each column (so they’re comparable on 0–1 scale)
normalized_means = grouped_data / grouped_data.max()


normalized_means.plot(
    kind='bar',
    figsize=(10,8),
    color=['#4C72B0', '#55A868']
)
plt.title('Normalized Average of Credit Utilization Ratio and Number of Loans by Credit Score')
plt.xlabel('Credit Score Category')
plt.ylabel('Normalized Average Value (0–1 scale)')
plt.xticks(rotation=0)
plt.legend(['Credit Utilization Ratio', 'Number of Loans'])
plt.show()

# %%
# Encode Credit_Score to numeric scale for correlation
score_map = {'Poor': 1, 'Standard': 2, 'Good': 3}
data['Credit_Score_Num'] = data['Credit_Score'].map(score_map)

# Compute correlation values
corr_util = data['Credit_Score_Num'].corr(data['Credit_Utilization_Ratio'])
corr_loan = data['Credit_Score_Num'].corr(data['Num_of_Loan'])

print("Correlation with Credit Utilization Ratio:", corr_util)
print("Correlation with Number of Loans:", corr_loan)
# Out:
# Correlation with Credit Utilization Ratio: 0.04579286731895937
# Correlation with Number of Loans: -0.35835464279655066

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As mentioned before with the categorical data type of credit score relationship is better recognizable with bar plots.
#
# Also since we are comparing the relation strength of two numerical variables this time i normalized both the means of the variables, so they are easily comparable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Credit Utilization Ratio has a little positive correlation where as No of loans has very prominent negative correlation with credit score.
#
# The correlation calculation also tells the same.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight obviously adds a new reliable parameter no of loans which has negative weightage on calculating the credit score.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#Credit Score vs Number of Credit Card

adequate_ratio = 30

data['Managed_Credit_Utilization_Ratio'] = data['Credit_Utilization_Ratio'] <= adequate_ratio

grouped_data = data.groupby(['Credit_Score', 'Managed_Credit_Utilization_Ratio'])['Num_Credit_Card'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(x='Credit_Score', y='Num_Credit_Card', hue='Managed_Credit_Utilization_Ratio', data=grouped_data, order=['Poor', 'Standard', 'Good'])

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is clear about the relationship of number of credit cards with credit_score for the same reason as before.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a negative correlation b/w number of credit cards and credit score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# With this insight we now can include number of credit card with a negative weightage to estimate credit score.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#Credit score vs Number of delayed payments
grouped_data = data.groupby('Credit_Score')['Num_of_Delayed_Payment'].mean().reindex(['Poor', 'Standard', 'Good'])

plt.figure(figsize=(8, 6))

sns.barplot(
    x=grouped_data.index,
    y=grouped_data.values,
    hue=grouped_data.index,
    palette='viridis',
    legend=False
)

plt.xlabel('Credit Score Category')
plt.ylabel('Average Number of Delayed Payments')
plt.title('Average Number of Delayed Payments by Credit Score Category')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Same reason as before.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a negative correlation between number of delayed payments and credit score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Number of delayed payments can be considered a parameter for finding credit score with negative weightage.

# %% [markdown]
# #### Chart - 5

# %%
grouped_data = data[['Customer_ID', 'Age_Group', 'Credit_Score']].drop_duplicates().groupby(['Age_Group', 'Credit_Score']).count().reset_index()

grouped_data[grouped_data['Credit_Score'] == 'Poor'].set_index('Age_Group')['Customer_ID']
# Out:
# Age_Group
# 10-20     800
# 20-30    1647
# 30-40    1623
# 40-50    1107
# 50-60     226
# Name: Customer_ID, dtype: int64

# %%
# Chart - 5 visualization code
#Credit Score population by age group
def agegroup(x):
  if x < 20:
    return '10-20'
  if x < 30:
    return '20-30'
  if x < 40:
    return '30-40'
  if x < 50:
    return '40-50'
  if x < 60:
    return '50-60'
  return '60+'

data['Age_Group'] = data['Age'].apply(agegroup)

grouped_data = data[['Customer_ID', 'Age_Group', 'Credit_Score']].drop_duplicates().groupby(['Age_Group', 'Credit_Score']).count().reset_index()

plt.figure(figsize=(10, 6))

poor_counts = grouped_data[grouped_data['Credit_Score'] == 'Poor'].set_index('Age_Group')['Customer_ID']
standard_counts = grouped_data[grouped_data['Credit_Score'] == 'Standard'].set_index('Age_Group')['Customer_ID']
good_counts = grouped_data[grouped_data['Credit_Score'] == 'Good'].set_index('Age_Group')['Customer_ID']

plt.bar(grouped_data['Age_Group'].unique(), poor_counts, label='Poor', color='#2d6fd2')
plt.bar(grouped_data['Age_Group'].unique(), standard_counts, bottom=poor_counts, label='Standard', color='#e481c3')
plt.bar(grouped_data['Age_Group'].unique(), good_counts, bottom=poor_counts+standard_counts,label='Good', color='#d26f2d')

plt.xlabel('Age Group')
plt.ylabel('Number of Customers')
plt.title('Number of Customers by Age Group and Credit Score')
plt.legend()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Like Credit_Score Age Group's also categorical and we are having other variable that is count of customers.
# Since each customer has a 8 records corresponding to 8 months i had to first remove duplicates based on the target columns so that there is only one record for each customer. Bar graph is the best for categorical vs numerical but stacked bar graph is best if we need to represent distribution of other variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Regarding credit score distribution, In all age groups the dominant credit score is 'Standard' and least dominant is 'Good'. Other key things to note is that in age group '10-20' the 'Good' credit score is scarce where as in '50-60' the 'Poor' credit score is scarce.
#
# Other probably not so relevant thing is most of the customers are in age groups '20-40'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In age group '10-20' the relative ratio of 'Poor' credit score count to the whole age group head count is the highest. So it could have a negative feedback to the age group's credit score.

# %% [markdown]
# #### Chart - 6

# %%
grouped_data = data.groupby(['Month', 'Credit_Score'])['Customer_ID'].count().reset_index()
grouped_data

# %%
# Chart - 6 visualization code
#Credit score population by month
grouped_data = data.groupby(['Month', 'Credit_Score'])['Customer_ID'].count().reset_index()

# Plot grouped bar chart
plt.figure(figsize=(10, 6))

poor_counts = grouped_data[grouped_data['Credit_Score'] == 'Poor']['Customer_ID']
standard_counts = grouped_data[grouped_data['Credit_Score'] == 'Standard']['Customer_ID']
good_counts = grouped_data[grouped_data['Credit_Score'] == 'Good']['Customer_ID']

plt.plot(np.arange(1, 9), poor_counts, label='Poor', color='#2d6fd2')
plt.plot(np.arange(1, 9), standard_counts, label='Standard', color='#e481c3')
plt.plot(np.arange(1, 9), good_counts, label='Good', color='#d26f2d')

plt.xlabel('Month')
plt.ylabel('Number of Customers')
plt.title('Number of Customers by Month per each Credit Score')
plt.legend()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Its Numerical(Month) vs Numerical(Count) so line plot is the best.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In Month april there is a dip in Standard customers where as there is a spike in Good customers. The Poor customer count is nearly a straight line throuout all the months. The Customers count distribution through out all months have the order Standard > Poor > Good.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The dip and spike in Standard and Good customers count can possibly insinuate that in the month april some customers who have standard credit score might perform well to promote to good.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
#Occupatiuon vs Credit Score

grouped_data = data[['Occupation', 'Customer_ID', 'Credit_Score']].drop_duplicates() \
.groupby(['Occupation', 'Credit_Score'])['Customer_ID'].count().reset_index()

poor_counts = grouped_data[grouped_data['Credit_Score'] == 'Poor'].set_index('Occupation')['Customer_ID']
standard_counts = grouped_data[grouped_data['Credit_Score'] == 'Standard'].set_index('Occupation')['Customer_ID']
good_counts = grouped_data[grouped_data['Credit_Score'] == 'Good'].set_index('Occupation')['Customer_ID']

plt.figure(figsize=(12, 8))

plt.barh(grouped_data['Occupation'].unique(), poor_counts, label='Poor', color='#2d6fd2')
plt.barh(grouped_data['Occupation'].unique(), standard_counts, left=poor_counts, label='Standard', color='#e481c3')
plt.barh(grouped_data['Occupation'].unique(), good_counts, left=poor_counts+standard_counts,label='Good', color='#d26f2d')

plt.ylabel('Occupation')
plt.xlabel('Number of Customers')
plt.title('Number of Customers by Occupation and Credit Score')
plt.legend()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Its a Category vs Count distribution. There are many values for Occupation category so horizontal stacked bar chart would be best.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Nothing much. As usual Standard credit score is pretty plenty for every occupation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# No particulaar insight

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Using the variables that had a significant correlation with credit score to estimate future credit score is the solution we can infer from the analysis.
# Useful variables that we have seen so far are annual income, credit utilization ratio, number of credit cards, no of loans, number of delayed payments.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# We answered all key enquiries we had and here are the following:
# 1. Does a higher annual income correlate with higher credit score?
#
#     A: Yes they are positively correlated
#
# 2. Does the credit utilization ratio have a greater impact on the credit scores than the total number of loans taken?
#
#     A: No Number of loans is more correlated although negative.
#
# 3. Is having higher number of credit cards associated with a higher credit score assuming the credit utilization ratio is managed well?
#
#     A: No, Higher number of credit cards correspond to low credit score.
#
# 4. Is there a negative correlation between the number of delayed payments and credit score?
#
#     A: Yes, there is negative correlation.
#
# 5. What is the distribution of credit scores across different age groups?
#
#     A: Standard score is more dominant in all age groups and Good is least dominant.
#
# 6. Are there noticeable trends or seasonal patterns in credit scores based on month of the year?
#
#     A: There is dip in Standard credit score customers and spike in Good credit score customers in the month of April.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
